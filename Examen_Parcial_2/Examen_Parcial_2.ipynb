# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/en/thumb/0/02/Logo_Tecnologico_de_Monterrey.svg/800px-Logo_Tecnologico_de_Monterrey.svg.png" width=300px/>

# %% [markdown]
# <h1><center>Campus Ciudad de México,
# Escuela Ingeniería y Ciencias,
# Computación</center></h1>
#
# <h3><center>Course: TC2010.500 (Intelligent Systems)</center>
# <center>Professor: Mauricio Rosales Rivera</center>
# <center>Second Partial Evaluation</center></h3>
#
# <h3><center>Date: October 30, 2020</center></h3>
#
# ---
#
# <h3>Grade: </h3>
#
# ---
# <h4><center>Student's information</center></h4>
# <h4>Names:
#   <strong>Carlos Julian Herrera, Ali Villegas, Alfredo Quintero </strong>
# </h4>
# <h4>Students ID:
#   <strong>A01114097, A01337596, A01337630 </strong>
# </h4>
#  <h4>Github:</h4>
#  <ul>
#   <li>
#     <a href="https://github.com/JulianHerreraH/Sistemas_Inteligentes">
#       Github Julian
#     </a>
#   </li>
#   <li>
#     <a href="https://github.com/AliVillegas/Sistemas-Inteligentes">
#       Github Ali
#     </a>
#   </li>
#     <li>
#     <a href="https://github.com/alfredoqt/sistemas-inteligentes">
#       Github Alfredo
#     </a>
#   </li>
#  </ul>

# %% [markdown]
# Apegándome al Código de Ética de los Estudiantes del Tecnológico de Monterrey, me comprometo a que mi actuación en este examen esté regida por la honestidad académica. En congruencia con el compromiso adquirido al firmar dicho código, realizaré este examen de forma honesta y personal, para reflejar, a través de él, mi conocimiento y aceptar, posteriormente, la evaluación obtenida.

# %% [markdown]
# # <font color="brown">Examen Parcial 2 - Sistemas Inteligentes</font>
#
# ---
#
# Indicaciones: El examen abarca los temas vistos en los Módulos 3 y 4.
#
# En la parte teórica, se evalua la correcta descripción de los términos.
#
# En la parte práctica, se evalua el desarrollo adecuado de la metodología para el ajuste de los datos, modelos y métricas de los mismos.
#
# * Fecha de liberación del examen: Jueves 29 de octubre.
# * Fecha límite de entrega: Martes 03 de noviembre hasta las 23:59 hrs
#
# Esta notebook deberá contener el nombre completo, matrícula y el link correspondiente al GitHub de cada integrante.
#
# En caso de no tener la información aquí solicitada, no se evaluará el examen.

# %% [markdown]
# **Para poder correr la parte práctica usamos el csv de datos, en colab se puede cargar subiendo los archivos**

# %% [markdown]
# ---
# ---
# ---
# # <font color="red">Sección Teórica</font>
#
# ### (30 puntos)
#
# ---

# %% [markdown]
# ---
# ### <font color='blue'>P1.- ¿Qué son las Redes Bayesianas? Realiza una descripción y proporciona un breve ejemplo.</font>
#
# **Recuerda la notebook teórica de ML**
#
# (Valor: 3 puntos)
#
# ---

# %% [markdown]
# >**Una red bayesiana es un modelo probabilístico grafico (PGM) que representa un conjunto de variables con sus dependencias condicionales. Estas se pueden observar en un grafo acíclico dirigido (DAG). Estas redes son útiles para tomar eventos que han pasado y predecir cual de las causas con los factores contribuyentes.
# Un ejemplo de red bayesiana es crear la representación de la causas de una enfermedad mortal.**

# %% [markdown]
# ---
# ### <font color='blue'>P2.- Realiza una descripción del Clasificador Bayes ingenuo (Naïve Bayes) y proporciona un breve ejemplo ya sea escrito o en código</font>
# (Valor: 3 puntos)
#
# ---

# %% [markdown]
# >**Está basada en el teorema de Bayes y es una técnica de clasificación supervisada. Este clasificador asume que existen independencia entre los atributos.  Es uno de los más simples y rápidos.
# Un ejemplo de este clasificador puede ser el de clasificar especies de perros, basándose en su tamaño, color y estructura**

# %% [markdown]
# ---
# ### <font color='blue'>P3.- Realiza una descripción de la Inferencia Bayesiana</font>
# (Valor: 3 puntos)
#
# ---

# %% [markdown]
# >**La inferencia bayesiana nos muestra cómo se debe actualizar nuestras suposiciones a medida que observamos datos. Usando inferencia bayesiana, la evidencia es observada y de acuerdo con esto se calcula un estimado planteado en la hipótesis. Al usar inferencia, es bueno tener una mayor cantidad de datos ya que proporcionan resultados mas completos**

# %% [markdown]
# ---
# ### <font color='blue'>P4.-  ¿Qué es el Aprendizaje Máquina?</font>
#
# (Valor: 3 Puntos)
#
# ---

# %% [markdown]
# >**El aprendizaje máquina, también llamado Machine Learning, es un campo de estudio de la computación. En general, ML se define como un programa que aprende sin que se le den instrucciones explícitamente. El programa aprende de experiencias mientras que realiza alguna tarea las cuales tienen medias de desempeño.**

# %% [markdown]
# ---
# ### <font color='blue'>P5.- ¿Cuáles son los tipos de aprendizaje máquina?. Además proporciona la diferencia entre ellas.</font>
#
# (Valor: 3 Puntos)
#
# ---

# %% [markdown]
# >**Hay dos tipos de aprendizaje maquina:**
# - **Supervisado: El programa cuenta con un set predefinido de ejemplos de entrenamiento que sirven para entrenarlo, con estos datos puede llegar a una mejor conclusión después de que le pasan más datos.**
# - **No supervisado: El programa no cuenta con datos de entrenamiento previo, dados los datos debe encontrar patrones y relaciones para llegar a conclusiones**

# %% [markdown]
# ---
# ### <font color='blue'>P6.- Describe el Método del Gradiente Descendiente y proporciona un breve ejemplo de su funcionamiento</font>
# (Valor: 6 Puntos)
#
# ---

# %% [markdown]
# >**Es un algoritmo de optimización usado para entrenar modelos de ML. Usa iteraciones para minimizar una función a su mínimo local. Permite predecir comportamientos. En este método se empieza definiendo parámetros iniciales y a partir de estos se usa el calculo para ajustar los valores iterativamente hasta encontrar la función de consto mínimo.**

# %% [markdown]
# ---
# ### <font color="blue">P7.- ¿Qué son los datos y los atributos?</font>
#
# (Valor: 3 Puntos)
#
# ---

# %% [markdown]
# >- **Los datos son una colección de objetos y los atributos que les corresponden. Se les conoce con otros nombres son: registro, punto, vector, etc.**
# - **Los atributos son características de los objetos, un ejemplo es el color de un perro. Para analizar estas características se asignan números o símbolos.**

# %% [markdown]
# ---
# ### <font color="blue">P8.- Describe las tres características generales de los conjuntos de datos: dimensionalidad, dispersión y resolución.</font>
#
# (Valor: 3 Puntos)
#
# ---

# %% [markdown]
# >- **Dimensionalidad: es el numero de atributos que tienen los objetos. Se conoce como alta dimensionalidad si hay muchos atributos. Esto presenta dificultades a la hora de analizar los datos.**
# - **Resolución:  el nivel de resolución dicta los patrones en los datos. Una resolución fina no permite que los patrones sean visibles y los oculta en ruido blanco. Con una resolución gruesa el patrón desaparece.**
# - **Dispersión: se denomina datos dispersos a los datos asimétricos donde la mayoría de los tributos tienen valores de 0**

# %% [markdown]
# ---
# ### <font color="blue">P9.- ¿Qué es el pre-procesamiento de los datos? Y ¿cuáles son los pasos utilizados para éste?</font>
#
# (Valor: 3 Puntos)
#
# ---

# %% [markdown]
# >**Se define preprocesamiento de datos a los pasos llevado a cabo para lograr que los datos sean más adecuados para la minería. Los pasos se pueden dividir en dos categorías:**
# - **Seleccionar objectos de datos y atributos para análisis**
# - **Crear y/o cambiar los atributos**

# %% [markdown]
# ---
# ---
# ---
# # <font color="red">Sección Práctica</font>
#
# ### (70 puntos)
#
# ---

# %% [markdown]
# ---
# ### <font color="blue">P1.- Construye un perceptrón para realizar un análisis del conjunto de datos **Iris**</font>
#
#
# (Valor: 30 Puntos)
#
# ---

# %% [markdown]
# #### Nota: En esta sección, se realizará algo bastante parecido a lo que habíamos visto del perceptrón con el dataset de Iris, pero ahora usando las librerías de sklearn

# %%
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Perceptron
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import numpy as np
import pandas as pd
import seaborn as seabornGraphs
import matplotlib.pyplot as plt

# %%
irisDataSet = datasets.load_iris()

# %%
irisDataSet.DESCR
# Out:
# '.. _iris_dataset:\n\nIris plants dataset\n--------------------\n\n**Data Set Characteristics:**\n\n    :Number of Instances: 150 (50 in each of three classes)\n    :Number of Attributes: 4 numeric, predictive attributes and the class\n    :Attribute Information:\n        - sepal length in cm\n        - sepal width in cm\n        - petal length in cm\n        - petal width in cm\n        - class:\n                - Iris-Setosa\n                - Iris-Versicolour\n                - Iris-Virginica\n                \n    :Summary Statistics:\n\n    ============== ==== ==== ======= ===== ====================\n                    Min  Max   Mean    SD   Class Correlation\n    ============== ==== ==== ======= ===== ====================\n    sepal length:   4.3  7.9   5.84   0.83    0.7826\n    sepal width:    2.0  4.4   3.05   0.43   -0.4194\n    petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)\n    petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)\n    ============== ====
# ...

# %% [markdown]
# **Nota: como es un ejemplo clásico, contiene la información de las referencias del dataset**

# %%
xDat = irisDataSet.data
yDat = irisDataSet.target

# %%
xTraining, xTest, yTraining, yTest = train_test_split(xDat, yDat, test_size=0.3) # 30% en test data

# %%
sc = StandardScaler()
sc.fit(xTraining)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
stdXTrain = sc.transform(xTraining)
stdXTest = sc.transform(xTest)

# %%
ppn = Perceptron(eta0=0.01, random_state=5)
ppn.fit(stdXTrain, yTraining)
# Out:
# Perceptron(alpha=0.0001, class_weight=None, early_stopping=False, eta0=0.01,
#            fit_intercept=True, max_iter=1000, n_iter_no_change=5, n_jobs=None,
#            penalty=None, random_state=5, shuffle=True, tol=0.001,
#            validation_fraction=0.1, verbose=0, warm_start=False)

# %%
predictionY = ppn.predict(stdXTest)

# %%
predictionY
# Out:
# array([2, 2, 2, 1, 1, 1, 2, 2, 0, 2, 0, 0, 2, 2, 2, 2, 2, 0, 0, 2, 1, 2,
#        2, 1, 2, 0, 0, 1, 0, 2, 2, 0, 2, 0, 2, 1, 2, 0, 2, 0, 0, 2, 2, 2,
#        1])

# %%
print('Accuracy: %.2f' % accuracy_score(yTest, predictionY))
# Out:
# Accuracy: 0.73

# %% [markdown]
# ##### Como podemos observar, ya evaluando todo el dataset ( a diferencia del ejercicio del perceptrón **hecho en casa** ), no le va tan mal...

# %% [markdown]
# Por último... muestra un pairplot de todo el dataset. Convierte primero el dataset de iris de sklearn a un dataframe :)

# %%
data = pd.DataFrame(data= np.c_[iris['data'], iris['target']],
                     columns= iris['feature_names'] + ['target'])
print(data)
# Out:
#      sepal length (cm)  sepal width (cm)  ...  petal width (cm)  target
# 0                  5.1               3.5  ...               0.2     0.0
# 1                  4.9               3.0  ...               0.2     0.0
# 2                  4.7               3.2  ...               0.2     0.0
# 3                  4.6               3.1  ...               0.2     0.0
# 4                  5.0               3.6  ...               0.2     0.0
# ..                 ...               ...  ...               ...     ...
# 145                6.7               3.0  ...               2.3     2.0
# 146                6.3               2.5  ...               1.9     2.0
# 147                6.5               3.0  ...               2.0     2.0
# 148                6.2               3.4  ...               2.3     2.0
# 149                5.9               3.0  ...               1.8     2.0
#
# [150 rows x 5 columns]

# %%
seabornGraphs.pairplot(data, hue="target", palette="tab10", markers=["o", "s", "D"])

# %% [markdown]
# ---
# ### <font color="blue">P2.- Aplicarás diversos algoritmos de clasificación para el conjunto de datos de información bancaria</font>
#
#
# (Valor: 30 Puntos)
#
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Como puedes apreciar, el dataset del banco está separado por **;**, ajusta un poco el método de pd.read_csv para poder crear el dataframe correspondiente

# %%
bankData = pd.read_csv('./bank-additional-full.csv', sep = ';')

# %%
bankData
# Out:
#        age          job  marital  ... euribor3m nr.employed    y
# 0       56    housemaid  married  ...     4.857      5191.0   no
# 1       57     services  married  ...     4.857      5191.0   no
# 2       37     services  married  ...     4.857      5191.0   no
# 3       40       admin.  married  ...     4.857      5191.0   no
# 4       56     services  married  ...     4.857      5191.0   no
# ...    ...          ...      ...  ...       ...         ...  ...
# 41183   73      retired  married  ...     1.028      4963.6  yes
# 41184   46  blue-collar  married  ...     1.028      4963.6   no
# 41185   56      retired  married  ...     1.028      4963.6   no
# 41186   44   technician  married  ...     1.028      4963.6  yes
# 41187   74      retired  married  ...     1.028      4963.6   no
#
# [41188 rows x 21 columns]

# %% [markdown]
# Muestren la forma dataframe, así como identifica la columna que será nuestro target.

# %%
bankData.head()
bankData.info()
bankData.isnull().any()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %% [markdown]
# Usaremos la función de pd.get_dummies para transformar la variable categórica a numérica

# %%
yD = pd.get_dummies(bankData['y'], columns = ['y'], drop_first = True)
yD
# Out:
#        yes
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ...    ...
# 41183    1
# 41184    0
# 41185    0
# 41186    1
# 41187    0
#
# [41188 rows x 1 columns]

# %% [markdown]
# A partir del ejercicio de EDA_Predicción, nos basaremos para realizar las modificaciones correspondientes al dataframe como ahí se muestra. Pero la única diferencia será que aquí utilizarán menos columnas (bank_client y bank_related).

# %%
bankClients = bankData.iloc[: , 0:7]
bankClients.head()
# Out:
#    age        job  marital    education  default housing loan
# 0   56  housemaid  married     basic.4y       no      no   no
# 1   57   services  married  high.school  unknown      no   no
# 2   37   services  married  high.school       no     yes   no
# 3   40     admin.  married     basic.6y       no      no   no
# 4   56   services  married  high.school       no      no  yes

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder_X = LabelEncoder()
bankClients['job']      = labelencoder_X.fit_transform(bankClients['job']) 
bankClients['housing']  = labelencoder_X.fit_transform(bankClients['housing']) 
bankClients['loan']     = labelencoder_X.fit_transform(bankClients['loan'])
bankClients['marital']  = labelencoder_X.fit_transform(bankClients['marital']) 
bankClients['education']= labelencoder_X.fit_transform(bankClients['education']) 
bankClients['default']  = labelencoder_X.fit_transform(bankClients['default'])

# %%
def age(dataframe):
    dataframe.loc[dataframe['age'] <= 32, 'age'] = 1
    dataframe.loc[(dataframe['age'] > 32) & (dataframe['age'] <= 47), 'age'] = 2
    dataframe.loc[(dataframe['age'] > 47) & (dataframe['age'] <= 70), 'age'] = 3
    dataframe.loc[(dataframe['age'] > 70) & (dataframe['age'] <= 98), 'age'] = 4
           
    return dataframe

age(bankClients);

# %%
bankClients.head()
# Out:
#    age  job  marital  education  default  housing  loan
# 0    3    3        1          0        0        0     0
# 1    3    7        1          3        1        0     0
# 2    2    7        1          3        0        2     0
# 3    2    0        1          1        0        0     0
# 4    3    7        1          3        0        0     2

# %% [markdown]
# Ahora, el siguiente bloque...

# %%
bankRelated = bankData.iloc[: , 7:11]
bankRelated.head()
# Out:
#      contact month day_of_week  duration
# 0  telephone   may         mon       261
# 1  telephone   may         mon       149
# 2  telephone   may         mon       226
# 3  telephone   may         mon       151
# 4  telephone   may         mon       307

# %% [markdown]
# ### ¿Cuántos outliers hay presentes en estas gráficas y que podrían ustedes decir respecto a estos casos?
#
# ---
#
# Muestra las duraciones de las llamadas tanto en minutos como en cuartiles y proporciona tu explicación

# %%
fig, (ax1, ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (13, 5))
sns.boxplot(x = 'duration', data = bankRelated, orient = 'v', ax = ax1)
ax1.set_xlabel('Calls', fontsize=10)
ax1.set_ylabel('Duration', fontsize=10)
ax1.set_title('Calls Distribution', fontsize=10)
ax1.tick_params(labelsize=10)

sns.histplot(bankRelated['duration'], ax = ax2)
sns.despine(ax = ax2)
ax2.set_xlabel('Duration Calls', fontsize=10)
ax2.set_ylabel('Occurence', fontsize=10)
ax2.set_title('Duration x Ocucurence', fontsize=10)
ax2.tick_params(labelsize=10)

plt.subplots_adjust(wspace=0.5)
plt.tight_layout()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_core.py:1303: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))

# %% [markdown]
# Apliquemos una codificación de las variables categóricas a numéricas

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder_X = LabelEncoder()
bankRelated['contact']     = labelencoder_X.fit_transform(bankRelated['contact']) 
bankRelated['month']       = labelencoder_X.fit_transform(bankRelated['month']) 
bankRelated['day_of_week'] = labelencoder_X.fit_transform(bankRelated['day_of_week'])

# %%
bankRelated.head()
# Out:
#    contact  month  day_of_week  duration
# 0        1      6            1       261
# 1        1      6            1       149
# 2        1      6            1       226
# 3        1      6            1       151
# 4        1      6            1       307

# %%
bank_final= pd.concat([bank_client, bankRelated], axis = 1)
bank_final.shape
# Out:
# (41188, 11)

# %% [markdown]
# Realizaremos el split de los datos en un 80/20

# %%
XTraining, XTest, yTraining, yTest = train_test_split(bankClients, yD, test_size=0.2, random_state=0)

# %% [markdown]
# Además de hacer el split de los datos, también deberán aplicar un escalar a los datos de X.

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
XTraining = sc_X.fit_transform(XTraining)
XTest = sc_X.transform(XTest)

# %% [markdown]
# Posteriormente, aplicarán los algoritmos de:
#     * Regresión logística
#     * K vecinos cercanos (KNN)
#     * Árbol de decisión (DT)
#     * Bosque Aleatorio (RF)
#
# Sin ninguna especie de asignación de hiperparámetros

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
alg1 = LogisticRegression().fit(XTraining, yTraining)
resultAlg1 = alg1.score(XTest,yTest)
alg2 = KNeighborsClassifier().fit(XTraining, yTraining)
resultAlg2 = alg2.score(XTest, yTest)
alg3 =  DecisionTreeClassifier().fit(XTraining, yTraining)
resultAlg3 = alg3.score(XTest,yTest)
alg4 = RandomForestClassifier().fit(XTraining, yTraining)
resultAlg4 = alg4.score(XTest,yTest)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]

# %% [markdown]
# Muestra en una tabla las puntuaciones de los algoritmos y, en su caso, ¿cuál habrá sido el que mejor comportamiento tendría?

# %%
t = pd.DataFrame({'Models':['Random Forest Classifier', 'Logistic Model', 'Neighbors K-near', 'Decision Tree Classifier'],
                    'Score': [resultAlg4,
                              resultAlg1, 
                              resultAlg2, 
                              resultAlg3]
                  })
t
# Out:
#                      Models     Score
# 0  Random Forest Classifier  0.882253
# 1            Logistic Model  0.888444
# 2          Neighbors K-near  0.869629
# 3  Decision Tree Classifier  0.881646

# %% [markdown]
# Finalmente, muestren un reporte de clasificación de los dos mejores algoritmos

# %%
from sklearn.metrics import classification_report

yPrediction = alg4.predict(XTest)
print(classification_report(yTest, yPrediction, target_names = ['0', '1']))

yPrediction = alg1.predict(XTest)
print(classification_report(yTest, yPrediction, target_names = ['0', '1']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.99      0.94      7319
#            1       0.28      0.04      0.06       919
#
#     accuracy                           0.88      8238
#    macro avg       0.59      0.51      0.50      8238
# weighted avg       0.82      0.88      0.84      8238
#
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94      7319
#            1       0.00      0.00      0.00       919
#
#     accuracy                           0.89      8238
#    macro avg       0.44      0.50      0.47      8238
# weighted avg       0.79      0.89      0.84      8238
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ---
# ---
# ---
# # <font color="red">Sección Extra</font>
#
# ### (40 puntos)
#
# ---

# %% [markdown]
# ### Precio de Bitcoin. Predicción de ARIMA
#
# **Propósito**: Tener una plantilla simplificada para comprender el pronóstico de series de tiempo con el modelo ARIMA en Python, actuando más como un tutorial.
#
# **Objetivo**: Construir un modelo para pronosticar la demanda (tráfico de pasajeros) en Aviones. Los datos se clasifican en fecha / hora y los pasajeros que viajan por mes.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
from scipy import stats
import statsmodels.api as sm
import warnings
from itertools import product
from datetime import datetime
warnings.filterwarnings('ignore')
plt.style.use('seaborn-poster')
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ### P1.- ¿Qué es una serie de tiempo?

# %%
Sucesión de datos donde el tiempo es la variable independiente, y la variable dependiente es algo más

# %% [markdown]
# ### P2.- ¿Por qué y dónde se utiliza la serie de tiempo?

# %%
Se puede utilizar para saber cómo cambia una variable sobre el tiempo. El precio de una acción, por ejemplo

# %% [markdown]
# ### P3.- ¿Cuáles son los componentes de las series de tiempo?

# %% [markdown]
# Tendencia secular, Variación estacional, Variación cíclica, Variación aleatoria, Variación transiente
#
# Cargaremos el dataset de información de bitcoins

# %%
df = pd.read_csv('./bitstampUSD_1-min_data_2012-01-01_to_2020-09-14.csv', sep = ',')
df.head()
# Out:
#     Timestamp  Open  High  ...  Volume_(BTC)  Volume_(Currency)  Weighted_Price
# 0  1325317920  4.39  4.39  ...      0.455581                2.0            4.39
# 1  1325317980   NaN   NaN  ...           NaN                NaN             NaN
# 2  1325318040   NaN   NaN  ...           NaN                NaN             NaN
# 3  1325318100   NaN   NaN  ...           NaN                NaN             NaN
# 4  1325318160   NaN   NaN  ...           NaN                NaN             NaN
#
# [5 rows x 8 columns]

# %%
# Unix-time to 
df.Timestamp = pd.to_datetime(df.Timestamp, unit='s')

# Resampling to daily frequency
df.index = df.Timestamp
df = df.resample('D').mean()

# Resampling to monthly frequency
df_month = df.resample('M').mean()

# Resampling to annual frequency
df_year = df.resample('A-DEC').mean()

# Resampling to quarterly frequency
df_Q = df.resample('Q-DEC').mean()

# %%
# PLOTS
fig = plt.figure(figsize=[15, 7])
plt.suptitle('Bitcoin exchanges, mean USD', fontsize=22)

plt.subplot(221)
plt.plot(df.Weighted_Price, '-', label='By Days')
plt.legend()

plt.subplot(222)
plt.plot(df_month.Weighted_Price, '-', label='By Months')
plt.legend()

plt.subplot(223)
plt.plot(df_Q.Weighted_Price, '-', label='By Quarters')
plt.legend()

plt.subplot(224)
plt.plot(df_year.Weighted_Price, '-', label='By Years')
plt.legend()

plt.show()

# %% [markdown]
# ## Predecirán el precio de las bitcoins por meses...
# ### Verificación de estacionariedad y descomposición STL de la serie

# %%
df_month = df_month.dropna()
plt.figure(figsize=[15,7])
sm.tsa.seasonal_decompose(df_month.Weighted_Price).plot()
print("Dickey–Fuller test: p=%f" % sm.tsa.stattools.adfuller(df_month.Weighted_Price)[1])
plt.show()
# Out:
# Dickey–Fuller test: p=0.617866

# %%
df_month['Weighted_Price_box'], lmbda = stats.boxcox(df_month.Weighted_Price)
print("Dickey–Fuller test: p=%f" % sm.tsa.stattools.adfuller(df_month.Weighted_Price)[1])
# Out:
# Dickey–Fuller test: p=0.617866

# %%
df_month['prices_box_diff'] = df_month.Weighted_Price_box - df_month.Weighted_Price_box.shift(12)
print("Dickey–Fuller test: p=%f" % sm.tsa.stattools.adfuller(df_month.prices_box_diff[12:])[1])
# Out:
# Dickey–Fuller test: p=0.288535

# %%
# Regular differentiation
df_month['prices_box_diff2'] = df_month.prices_box_diff - df_month.prices_box_diff.shift(1)
plt.figure(figsize=(15,7))

# STL-decomposition
sm.tsa.seasonal_decompose(df_month.prices_box_diff2[13:]).plot()   
print("Dickey–Fuller test: p=%f" % sm.tsa.stattools.adfuller(df_month.prices_box_diff2[13:])[1])

plt.show()
# Out:
# Dickey–Fuller test: p=0.000002

# %%
# Initial approximation of parameters using Autocorrelation and Partial Autocorrelation Plots
plt.figure(figsize=(15,7))
ax = plt.subplot(211)
sm.graphics.tsa.plot_acf(df_month.prices_box_diff2[13:].values.squeeze(), lags=48, ax=ax)
ax = plt.subplot(212)
sm.graphics.tsa.plot_pacf(df_month.prices_box_diff2[13:].values.squeeze(), lags=48, ax=ax)
plt.tight_layout()
plt.show()

# %%
# Initial approximation of parameters
Qs = range(0, 2)
qs = range(0, 3)
Ps = range(0, 3)
ps = range(0, 3)
D=1
d=1
parameters = product(ps, qs, Ps, Qs)
parameters_list = list(parameters)
len(parameters_list)

# Model Selection
results = []
best_aic = float("inf")
warnings.filterwarnings('ignore')
for param in parameters_list:
    try:
        model=sm.tsa.statespace.SARIMAX(df_month.Weighted_Price_box, order=(param[0], d, param[1]), 
                                        seasonal_order=(param[2], D, param[3], 12)).fit(disp=-1)
    except ValueError:
        print('wrong parameters:', param)
        continue
    aic = model.aic
    if aic < best_aic:
        best_model = model
        best_aic = aic
        best_param = param
    results.append([param, model.aic])

# %%
# Best Models
result_table = pd.DataFrame(results)
result_table.columns = ['parameters', 'aic']
print(result_table.sort_values(by = 'aic', ascending=True).head())
print(best_model.summary())
# Out:
#       parameters         aic
# 11  (0, 1, 2, 1)  198.825567
# 23  (1, 0, 2, 1)  198.882307
# 19  (1, 0, 0, 1)  199.158323
# 21  (1, 0, 1, 1)  199.434530
# 7   (0, 1, 0, 1)  199.517849
#                                  Statespace Model Results
# ...
# Dep. Variable:                 Weighted_Price_box   No. Observations:                  106
# Model:             SARIMAX(0, 1, 1)x(2, 1, 1, 12)   Log Likelihood                 -94.413
# Date:                            Mon, 02 Nov 2020   AIC                            198.826
# Time:                                    01:55:39   BIC                            211.489
# Sample:                                12-31-2011   HQIC                           203.939
#                                      - 09-30-2020
# Covariance Type:                              opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### P4.- ¿Qué es ADF_Test, ACF, PACF, ARIMA y SARIMA? ¿Para qué se usan?

# %%
ADF Test
Augmented Dickey-Fuller Test
Prueba de raíz unitaria para muestra de serie de tiempo

ACF
Autocorrelation Function
Encuentra patrones repetitivos dentro de una señal, como la periodicidad de una señal en ruido o para identificar la frecuencia fundamental de una señal que no contiene el componente, pero aparecen numerosas frecuencias armónicas de esta.

PACF
Partial Autocorrelation Function
Se utiliza para el análisis de datos dirigido a la identificación de la medida del desfase en un modelo regresivo

ARIMA
Autoregressive Integrated Moving Average
Predice datos no cambiantes

SARIMA
Seasonal Autoregressive Integrated Moving Average
Predice datos no cambiantes con un componente de temporada

# %%
# STL-decomposition
plt.figure(figsize=(15,7))
plt.subplot(211)
best_model.resid[13:].plot()
plt.ylabel(u'Residuals')
ax = plt.subplot(212)
sm.graphics.tsa.plot_acf(best_model.resid[13:].values.squeeze(), lags=48, ax=ax)

print("Dickey–Fuller test:: p=%f" % sm.tsa.stattools.adfuller(best_model.resid[13:])[1])

plt.tight_layout()
plt.show()
# Out:
# Dickey–Fuller test:: p=0.000000

# %% [markdown]
# ### Predicciones...

# %%
# Inverse Box-Cox Transformation Function
def invboxcox(y,lmbda):
    if lmbda == 0:
        return(np.exp(y))
    else:
        return(np.exp(np.log(lmbda*y+1)/lmbda))

# %%
# Prediction
df_month2 = df_month[['Weighted_Price']]

# Crea una lista con fechas y que sea hasta el mes de mayo
date_list = [datetime(2020, 10, 31), datetime(2020, 11, 30),datetime(2020, 12, 31), datetime(2021, 1, 30), datetime(2021, 2, 28), datetime(2021, 3, 31), datetime(2021, 4, 30), datetime(2021, 5, 31)]
future = pd.DataFrame(index=date_list, columns= df_month.columns)
df_month2 = pd.concat([df_month2, future])
df_month2['forecast'] = invboxcox(best_model.predict(start=0, end=110), lmbda)
plt.figure(figsize=(18,7))
df_month2.Weighted_Price.plot()
df_month2.forecast.plot(color='r', ls='--', label='Predicted Weighted_Price')
plt.legend()
plt.title('Bitcoin exchanges, by months')
plt.ylabel('mean USD')
plt.show()

# %%
df_dude = df_month2[['Weighted_Price', 'forecast']]
df_dude
# Out:
#             Weighted_Price      forecast
# 2011-12-31        4.471603      1.000000
# 2012-01-31        6.208550      4.471604
# 2012-02-29        5.252527      6.208550
# 2012-03-31        4.962021      5.252527
# 2012-04-30        4.976547      4.962021
# ...                    ...           ...
# 2021-01-30             NaN           NaN
# 2021-02-28             NaN  15055.236989
# 2021-03-31             NaN           NaN
# 2021-04-30             NaN           NaN
# 2021-05-31             NaN           NaN
#
# [114 rows x 2 columns]

# %% [markdown]
# ### ¿Qué podemos inferir de estas cosas?

# %% [markdown]
# Hay tendencia alta en el segundo cuarto del año, y una tendencia baja a finales
